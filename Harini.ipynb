# %%
 from keras.datasets import mnist
 
data=mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
 ((X_train, Y_train), (x_test, y_test))=data

# %%
 X_train=X_train.reshape((X_train.shape[0],28*28)).astype('float32')
x_test=x_test.reshape((x_test.shape[0],28*28)).astype('float32')

# %%
 X_train=X_train/255
x_test=x_test/255

# %%
 from keras.utils import np_utils
 
Y_train=np_utils.to_categorical(Y_train)
y_test=np_utils.to_categorical(y_test)
 
num_classes=y_test.shape[1]
 
print(y_test.shape)
# Out:
# (10000, 10)

# %%
 from keras.models import Sequential
from keras.layers import Dense

# %%
 model=Sequential()
 
model.add(Dense(32,input_dim=28*28, activation='relu'))
 
model.add(Dense(64, activation='relu'))
 
model.add(Dense(10, activation='softmax'))

# %%
 model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
 model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                25120
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# =================================================================
# Total params: 27,882
# Trainable params: 27,882
# Non-trainable params: 0
# _________________________________________________________________

# %%
 model.fit(X_train, Y_train, epochs=10, batch_size=100)
# Out:
# Epoch 1/10
# 600/600 [==============================] - 2s 2ms/step - loss: 0.8095 - accuracy: 0.7682
# Epoch 2/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2117 - accuracy: 0.9381
# Epoch 3/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1550 - accuracy: 0.9542
# Epoch 4/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1264 - accuracy: 0.9620
# Epoch 5/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1118 - accuracy: 0.9671
# Epoch 6/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0962 - accuracy: 0.9702
# Epoch 7/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0861 - accuracy: 0.9732
# Epoch 8/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0749 - accuracy: 0.9777
# Epoch 9/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0686 - accuracy: 0.9790
# Epoch 10/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.0641 - accuracy: 0.9800

# %%
 scores=model.evaluate(x_test,y_test)
print(scores)
# Out:
# 313/313 [==============================] - 0s 977us/step - loss: 0.1040 - accuracy: 0.9689
# [0.10397826135158539, 0.9689000248908997]
